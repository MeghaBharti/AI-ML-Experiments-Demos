# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghaBharti/AI-ML-Experiments-Demos/blob/main/ML/Unsupervised-Learning/K-Means/K_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find the Centeroid of K-means:

# %%
from sklearn.cluster import KMeans
import numpy as np
X = np.array([[1, 2], [1, 4], [1, 0],
              [10, 2], [10, 4], [10, 0]])
kmeans = KMeans(n_clusters=2, random_state=0, n_init="auto").fit(X)
kmeans.labels_
kmeans.predict([[0, 0], [12, 3]])
kmeans.cluster_centers_
# Out:
# array([[10.,  2.],
#        [ 1.,  2.]])

# %% [markdown]
# Pictorial Representation of K-Means:

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np
from matplotlib.colors import ListedColormap

# Data points
X = np.array([[1, 2], [1, 4], [1, 0],
              [10, 2], [10, 4], [10, 0]])

# Apply KMeans clustering
kmeans = KMeans(n_clusters=2, random_state=0, n_init="auto").fit(X)

# Get cluster labels and centers
labels = kmeans.labels_
centers = kmeans.cluster_centers_

# Define the grid for the background coloring
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

# Predict cluster labels for each point in the grid
Z = kmeans.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Create a custom colormap
colors = ['#a6cee3', '#b2df8a']  # Light blue and green for clusters
cmap = ListedColormap(colors)

# Plot the background colors for each cluster
plt.contourf(xx, yy, Z, cmap=cmap, alpha=0.5)

# Plot the data points
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', s=100, label="Data Points")

# Plot the cluster centers
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='x', s=200, label="Cluster Centers")

# Annotate points for better understanding
for i, txt in enumerate(X):
    plt.annotate(f'({txt[0]}, {txt[1]})', (txt[0], txt[1]), textcoords="offset points", xytext=(5, 5), ha='center')

# Add legend and title
#plt.legend()
plt.legend(loc='center', bbox_to_anchor=(0.5,0.9), frameon=True)

plt.title("KMeans Clustering with Cluster Groups")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.grid(True)

# Show the plot
plt.show()
